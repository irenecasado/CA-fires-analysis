# %% [markdown]
# # CA Wildfire Causes Analysis
#
# The first module of this notebook allows you to analyze the number of acres burned by each of the different causes defined by Cal Fire between 1887 and 2020.
#
# The second module of this notebook allows you to analyze the same data in a shorter period of time: from 2000 to 2020.

# %% [markdown]
# ### Configuration:
# Let's begin by importing the Python tools necessary for the analysis.

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# Import Cal Fire Dataset

# %%
ca_fires = pd.read_csv("fires_data copy.csv") # Import database
pd.set_option('display.float_format', lambda x: '%.5f' % x) # To format Pandas scientific notation for floats

# %%
#ca_fires['YEAR_'] = ca_fires['YEAR_'].astype('object')
#year_rf = ca_fires['YEAR_'].str.split(".")
#ca_fires['YEAR_'].apply(np.floor)

# %% [markdown]
# ### Analysis:
# The data source is now prepared for analysis.

# %%
ca_fires.info() # Explore database
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21318 entries, 0 to 21317
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      21318 non-null  int64
#  1   YEAR_         21241 non-null  float64
#  2   STATE         21315 non-null  object
#  3   AGENCY        21313 non-null  object
#  4   UNIT_ID       21298 non-null  object
#  5   FIRE_NAME     21195 non-null  object
#  6   INC_NUM       20396 non-null  object
#  7   ALARM_DATE    15954 non-null  object
#  8   CONT_DATE     8638 non-null   object
#  9   CAUSE         21270 non-null  object
#  10  COMMENTS      4064 non-null   object
#  11  REPORT_AC     8767 non-null   float64
#  12  GIS_ACRES     21311 non-null  float64
#  13  C_METHOD      9096 non-null   object
#  14  OBJECTIVE     21123 non-null  object
#  15  FIRE_NUM      17313 non-null  object
#  16  Shape_Length  21318 non-null  float64
#  17  Shape_Area    21318 non-null  float64
# dtypes: float64(5), int64(1), object(12)
# memory usage: 2.9+ MB

# %% [markdown]
# ### Explore:
# We start to explore the different "CAUSES" included in our dataset.

# %%
ca_fires.head(3)
# Out:
#    OBJECTID      YEAR_       STATE  \
# 0     21440 2020.00000  California
# 1     21441 2020.00000  California
# 2     21442 2020.00000  California
#
#                                               AGENCY  \
# 0  California Department of Forestry and Fire Pro...
# 1  California Department of Forestry and Fire Pro...
# 2  California Department of Forestry and Fire Pro...
#
#                            UNIT_ID FIRE_NAME INC_NUM    ALARM_DATE  \
# 0  Nevada - Yuba - Placer CAL FIRE    NELSON   13212  6/18/20 0:00
# 1  Nevada - Yuba - Placer CAL FIRE   AMORUSO   11799   6/1/20 0:00
# 2  Nevada - Yuba - Placer CAL FIRE    ATHENS   18493  8/10/20 0:00
#
#       CONT_DATE                        CAUSE COMMENTS  REPORT_AC  GIS_ACRES  \
# 0  6/23/20 0:00               11 - Powerline      NaN  110.00000  109.60250
# 1   6/4/20 0:00            2 - Equipment Use      NaN  670.00000  685.58502
# 2   3/1/20 0:00  14 - Unknown / Unidentified      NaN   26.00000   27.30048
#
#          C_METHOD               OBJECTIVE FIRE_NUM  Shape_Length    Shape_Area
# 0  1 - GPS Ground  Suppression (Wildfire)      NaN    3252.52328  443544.67480
# 1  1 - GPS Ground  Suppression (Wildfire)      NaN    9653.76031 2774464.03400
# 2  1 - GPS Ground  Suppression (Wildfire)      NaN    1649.64324  110481.12530

# %%
ca_fires.CAUSE.describe() # Explore "CAUSE"
# Out:
# count                           21270
# unique                             18
# top       14 - Unknown / Unidentified
# freq                             9543
# Name: CAUSE, dtype: object

# %% [markdown]
# Filter down to number of wildfires due to each cause in California.

# %%
ca_fires.CAUSE.value_counts() # Number of fires by "CAUSE"
# Out:
# 14 - Unknown / Unidentified      9543
# 1 - Lightning                    3454
# 9 - Miscellaneous                3379
# 2 - Equipment Use                1246
# 7 - Arson                         903
# 5 - Debris                        723
# 10 - Vehicle                      454
# 11 - Powerline                    412
# 4 - Campfire                      380
# 3 - Smoking                       342
# 8 - Playing with fire             196
# 18 - Escaped Prescribed Burn       90
# 6 - Railroad                       80
# 15 - Structure                     21
# 19 - Illegal Alien Campfire        17
# 16 - Aircraft                      14
# 13 - Non-Firefighter Training      11
# 12 - Firefighter Training           5
# Name: CAUSE, dtype: int64

# %%
ca_fires.CAUSE.value_counts().reset_index() # Reformat table
# Out:
#                             index  CAUSE
# 0     14 - Unknown / Unidentified   9543
# 1                   1 - Lightning   3454
# 2               9 - Miscellaneous   3379
# 3               2 - Equipment Use   1246
# 4                       7 - Arson    903
# 5                      5 - Debris    723
# 6                    10 - Vehicle    454
# 7                  11 - Powerline    412
# 8                    4 - Campfire    380
# 9                     3 - Smoking    342
# 10          8 - Playing with fire    196
# 11   18 - Escaped Prescribed Burn     90
# 12                   6 - Railroad     80
# 13                 15 - Structure     21
# 14    19 - Illegal Alien Campfire     17
# 15                  16 - Aircraft     14
# 16  13 - Non-Firefighter Training     11
# 17      12 - Firefighter Training      5

# %% [markdown]
# ### Filter:
# You can run this filter with every cause.

# %%
my_cause = "11 - Powerline" # Filter by "CAUSE" - This filter can be use with any "CAUSE".

# %%
my_cause = ca_fires[ca_fires.CAUSE == my_cause] # Filter by "my chosen cause".

# %%
my_cause.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 21302
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      412 non-null    int64
#  1   YEAR_         412 non-null    float64
#  2   STATE         412 non-null    object
#  3   AGENCY        412 non-null    object
#  4   UNIT_ID       410 non-null    object
#  5   FIRE_NAME     411 non-null    object
#  6   INC_NUM       404 non-null    object
#  7   ALARM_DATE    402 non-null    object
#  8   CONT_DATE     357 non-null    object
#  9   CAUSE         412 non-null    object
#  10  COMMENTS      88 non-null     object
#  11  REPORT_AC     333 non-null    float64
#  12  GIS_ACRES     412 non-null    float64
#  13  C_METHOD      361 non-null    object
#  14  OBJECTIVE     410 non-null    object
#  15  FIRE_NUM      196 non-null    object
#  16  Shape_Length  412 non-null    float64
#  17  Shape_Area    412 non-null    float64
# dtypes: float64(5), int64(1), object(12)
# memory usage: 61.2+ KB

# %%
my_cause.head(3)
# Out:
#     OBJECTID      YEAR_       STATE  \
# 0      21440 2020.00000  California
# 14     21454 2020.00000  California
# 15     21455 2020.00000  California
#
#                                                AGENCY  \
# 0   California Department of Forestry and Fire Pro...
# 14                              Department of Defense
# 15  California Department of Forestry and Fire Pro...
#
#                             UNIT_ID  FIRE_NAME INC_NUM    ALARM_DATE  \
# 0   Nevada - Yuba - Placer CAL FIRE     NELSON   13212  6/18/20 0:00
# 14                              NaN  PAVE PAWS   17717   8/2/20 0:00
# 15  Nevada - Yuba - Placer CAL FIRE      RIOSA   12970  6/15/20 0:00
#
#        CONT_DATE           CAUSE              COMMENTS  REPORT_AC  GIS_ACRES  \
# 0   6/23/20 0:00  11 - Powerline                   NaN  110.00000  109.60250
# 14   8/2/20 0:00  11 - Powerline  Beale Air Force Base  532.00000  532.77338
# 15  6/15/20 0:00  11 - Powerline                   NaN   13.80000   13.69473
#
#           C_METHOD               OBJECTIVE FIRE_NUM  Shape_Length  \
# 0   1 - GPS Ground  Suppression (Wildfire)      NaN    3252.52328
# 14  1 - GPS Ground  Suppression (Wildfire)      NaN    7847.30461
# 15  1 - GPS Ground  Suppression (Wildfire)      NaN    1354.18817
#
#       Shape_Area
# 0   443544.67480
# 14 2156057.03300
# 15   55420.55591

# %% [markdown]
# ### Sorting Values:
# Here we analyze the number of acres burned in each fired related to our specified cause.

# %%
my_cause.sort_values("GIS_ACRES", ascending=False).head(3) # Sorting values - The most destructive fires caused by "my_cause"
# Out:
#        OBJECTID      YEAR_       STATE  \
# 20608     42055 2018.00000  California
# 21031     42478 2019.00000  California
# 15004     36451 2002.00000  California
#
#                                                   AGENCY  \
# 20608  California Department of Forestry and Fire Pro...
# 21031  California Department of Forestry and Fire Pro...
# 15004  California Department of Forestry and Fire Pro...
#
#                              UNIT_ID FIRE_NAME INC_NUM     ALARM_DATE  \
# 20608                 Butte CAL FIRE      CAMP   16737   11/8/18 0:00
# 21031  Sonoma - Lake - Napa CAL FIRE   KINCADE   19376  10/23/19 0:00
# 15004             San Diego CAL FIRE     PINES    5658   7/29/02 0:00
#
#            CONT_DATE           CAUSE COMMENTS    REPORT_AC    GIS_ACRES  \
# 20608  11/26/18 0:00  11 - Powerline          153336.00000 153335.56250
# 21031  11/10/19 0:00  11 - Powerline      NaN          NaN  77762.14063
# 15004   8/11/02 0:00  11 - Powerline      NaN  61690.00000  61691.23828
#
#              C_METHOD               OBJECTIVE FIRE_NUM  Shape_Length  \
# 20608  1 - GPS Ground  Suppression (Wildfire)      NaN  311935.27880
# 21031  1 - GPS Ground  Suppression (Wildfire)      NaN  186114.89530
# 15004     2 - GPS Air  Suppression (Wildfire)      777  193363.89810
#
#            Shape_Area
# 20608 620527017.80000
# 21031 314692204.70000
# 15004 249655581.00000

# %% [markdown]
# Here we are calculating the total number of acres burned due to our specified cause.

# %%
my_cause.GIS_ACRES.sum() # Calculation: number of acres burned due to "my_cause"
# Out:
# 525121.876570476

# %% [markdown]
# Here we are going to calculate the power line related fires over time.

# %%
powerlines_over_time = my_cause.groupby('YEAR_').value_counts().to_frame(name = "number_of_fires").reset_index()

# %%
powerlines_over_time.head(1)
# Out:
#        YEAR_  OBJECTID       STATE  \
# 0 2006.00000     33793  California
#
#                                               AGENCY  \
# 0  California Department of Forestry and Fire Pro...
#
#                          UNIT_ID  FIRE_NAME INC_NUM    ALARM_DATE  \
# 0  Humboldt - Del Norte CAL FIRE  CASTERLIN    5546  8/18/06 0:00
#
#       CONT_DATE           CAUSE                             COMMENTS  \
# 0  8/20/06 0:00  11 - Powerline  24.2 acres grass & 9.7 acres timber
#
#    REPORT_AC  GIS_ACRES                      C_METHOD               OBJECTIVE  \
# 0   33.90000   33.94157  7 - Mixed Collection Methods  Suppression (Wildfire)
#
#   FIRE_NUM  Shape_Length   Shape_Area  number_of_fires
# 0        0    2409.32156 137356.66720                1

# %%
over_time_analysis = powerlines_over_time.groupby('YEAR_').agg({'number_of_fires':'sum'})

# %%
over_time_analysis.head(20)
# Out:
#             number_of_fires
# YEAR_
# 2006.00000                6
# 2007.00000                6
# 2010.00000                1

# %%
alt.Chart(over_time_analysis).mark_line().encode(
    x="YEAR_",
    y="number_of_fires"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/vegalite/v4/api.py:2020, in Chart.to_dict(self, *args, **kwargs)
#    2018     copy.data = core.InlineData(values=[{}])
#    2019     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020 return super().to_dict(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/vegalite/v4/api.py:384, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     381 kwargs["context"] = context
#     383 try:
# --> 384     dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     385 except jsonschema.ValidationError:
#     386     dct = None
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:326, in SchemaBase.to_dict(self, validate, ignore, context)
#     324     result = _todict(self._args[0], validate=sub_validate, context=context)
#     325 elif not self._args:
# --> 326     result = _todict(
#     327         {k: v for k, v in self._kwds.items() if k not in ignore},
#     328         validate=sub_validate,
#     329         context=context,
#     330     )
#     331 else:
#     332     raise ValueError(
#     333         "{} instance has both a value and properties : "
#     334         "cannot serialize to dict".format(self.__class__)
#     335     )
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:60, in _todict(obj, validate, context)
#      58     return [_todict(v, validate, context) for v in obj]
#      59 elif isinstance(obj, dict):
# ---> 60     return {
#      61         k: _todict(v, validate, context)
#      62         for k, v in obj.items()
#      63         if v is not Undefined
#      64     }
#      65 elif hasattr(obj, "to_dict"):
#      66     return obj.to_dict()
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:61, in <dictcomp>(.0)
#      58     return [_todict(v, validate, context) for v in obj]
#      59 elif isinstance(obj, dict):
#      60     return {
# ---> 61         k: _todict(v, validate, context)
#      62         for k, v in obj.items()
#      63         if v is not Undefined
#      64     }
#      65 elif hasattr(obj, "to_dict"):
#      66     return obj.to_dict()
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:56, in _todict(obj, validate, context)
#      54 """Convert an object to a dict representation."""
#      55 if isinstance(obj, SchemaBase):
# ---> 56     return obj.to_dict(validate=validate, context=context)
#      57 elif isinstance(obj, (list, tuple, np.ndarray)):
#      58     return [_todict(v, validate, context) for v in obj]
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:326, in SchemaBase.to_dict(self, validate, ignore, context)
#     324     result = _todict(self._args[0], validate=sub_validate, context=context)
#     325 elif not self._args:
# --> 326     result = _todict(
#     327         {k: v for k, v in self._kwds.items() if k not in ignore},
#     328         validate=sub_validate,
#     329         context=context,
#     330     )
#     331 else:
#     332     raise ValueError(
#     333         "{} instance has both a value and properties : "
#     334         "cannot serialize to dict".format(self.__class__)
#     335     )
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:60, in _todict(obj, validate, context)
#      58     return [_todict(v, validate, context) for v in obj]
#      59 elif isinstance(obj, dict):
# ---> 60     return {
#      61         k: _todict(v, validate, context)
#      62         for k, v in obj.items()
#      63         if v is not Undefined
#      64     }
#      65 elif hasattr(obj, "to_dict"):
#      66     return obj.to_dict()
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:61, in <dictcomp>(.0)
#      58     return [_todict(v, validate, context) for v in obj]
#      59 elif isinstance(obj, dict):
#      60     return {
# ---> 61         k: _todict(v, validate, context)
#      62         for k, v in obj.items()
#      63         if v is not Undefined
#      64     }
#      65 elif hasattr(obj, "to_dict"):
#      66     return obj.to_dict()
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/utils/schemapi.py:56, in _todict(obj, validate, context)
#      54 """Convert an object to a dict representation."""
#      55 if isinstance(obj, SchemaBase):
# ---> 56     return obj.to_dict(validate=validate, context=context)
#      57 elif isinstance(obj, (list, tuple, np.ndarray)):
#      58     return [_todict(v, validate, context) for v in obj]
#
# File ~/.local/share/virtualenvs/irenecasado-ZyoYGYt9/lib/python3.9/site-packages/altair/vegalite/v4/schema/channels.py:40, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#      38 elif not (type_in_shorthand or type_defined_explicitly):
#      39     if isinstance(context.get('data', None), pd.DataFrame):
# ---> 40         raise ValueError("{} encoding field is specified without a type; "
#      41                          "the type cannot be inferred because it does not "
#      42                          "match any column in the data.".format(shorthand))
#      43     else:
#      44         raise ValueError("{} encoding field is specified without a type; "
#      45                          "the type cannot be automatically inferred because "
#      46                          "the data is not specified as a pandas.DataFrame."
#      47                          "".format(shorthand))
#
# ValueError: YEAR_ encoding field is specified without a type; the type cannot be inferred because it does not match any column in the data.
# alt.Chart(...)

# %% [markdown]
# ### Calculate Top Causes:
# Now we are going to group our dataset by the column "CAUSE" and calculate the sum of acres burned per cause.

# %%
top_causes = ca_fires.groupby(["CAUSE"]).GIS_ACRES.sum().reset_index().sort_values("GIS_ACRES", ascending=False).head(10)

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
top_causes.head(10) # Give us the top 10 Wildfires Causes.
# Out:
#                           CAUSE      GIS_ACRES
# 5   14 - Unknown / Unidentified 14276774.23483
# 0                 1 - Lightning 10256128.35803
# 17            9 - Miscellaneous  7722483.21870
# 15                    7 - Arson  1986704.64000
# 10            2 - Equipment Use  1820317.96200
# 12                 4 - Campfire  1341581.93841
# 1                  10 - Vehicle   696625.50782
# 13                   5 - Debris   632788.61895
# 2                11 - Powerline   525121.87657
# 11                  3 - Smoking   358641.51409

# %% [markdown]
# ### Examine the result:

# %%
alt.Chart(top_causes).mark_bar().encode(x = "GIS_ACRES", y=alt.Y('CAUSE:N', sort='-x')) # Create a chart – CAUSE/ACRES
# Out:
# alt.Chart(...)

# %%
alt.Chart(top_causes).mark_bar().encode(x = "GIS_ACRES", y=alt.Y('CAUSE:N', sort='-x')).properties(title="Top Wildfire Causes in CA") # Create a title
# Out:
# alt.Chart(...)

# %% [markdown]
# ## II Module: General Analysis - From 2010 to 2020
#
# Here we are performing the same analysis but limiting our data frame to 2010-2020.

# %%
ca_fires_2010 = ca_fires[ca_fires.YEAR_ > 2010] # Filter form 2010 to 2020

# %% [markdown]
# ### How many fires have been caused by each cause?

# %%
ca_fires_2010.CAUSE.value_counts().reset_index() # Reformat table
# Out:
#                            index  CAUSE
# 0    14 - Unknown / Unidentified   1180
# 1                  1 - Lightning    713
# 2              9 - Miscellaneous    440
# 3              2 - Equipment Use    406
# 4                   10 - Vehicle    235
# 5                 11 - Powerline    190
# 6                      7 - Arson    159
# 7                     5 - Debris    141
# 8                   4 - Campfire     97
# 9          8 - Playing with fire     37
# 10  18 - Escaped Prescribed Burn     32
# 11                   3 - Smoking     29
# 12                  6 - Railroad     10
# 13                15 - Structure      8
# 14                 16 - Aircraft      5

# %% [markdown]
# ### How many acres have been burned by each cause?

# %% [markdown]
# Now we are going to group our dataset by the column "CAUSE" and calculate the sum of acres burned per cause.

# %%
top_causes_2010 = ca_fires_2010.groupby(["CAUSE"]).GIS_ACRES.sum().reset_index().sort_values("GIS_ACRES", ascending=False).head(10)

# %%
top_causes_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CAUSE      10 non-null     object
#  1   GIS_ACRES  10 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 240.0+ bytes

# %%
top_causes_2010.head(10) # Top 10 wildfire cause between 2010 and 2020
# Out:
#                           CAUSE     GIS_ACRES
# 0                 1 - Lightning 5027323.08845
# 3   14 - Unknown / Unidentified 2772650.20402
# 14            9 - Miscellaneous 1206508.69531
# 1                  10 - Vehicle  539022.85201
# 9                  4 - Campfire  525163.29665
# 12                    7 - Arson  328349.90986
# 2                11 - Powerline  280708.10067
# 7             2 - Equipment Use  161898.77883
# 10                   5 - Debris   68728.89507
# 13        8 - Playing with fire   15277.16557

# %% [markdown]
# ### Examine the result:

# %%
alt.Chart(top_causes_2010).mark_bar().encode(x = "GIS_ACRES", y=alt.Y('CAUSE:N', sort='-x')).properties(title="Top Wildfire Causes in CA between 2010 and 2020") # Create a chart with title
# Out:
# alt.Chart(...)
